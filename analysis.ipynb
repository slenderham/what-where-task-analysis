# %%
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import glob
import h5py
import re
from scipy.ndimage import gaussian_filter
from tqdm import tqdm
import scipy.io as sio
from joblib import Parallel, delayed
import os
import pickle
import argparse
from matplotlib import pyplot as plt
import seaborn as sns

# %%
root_dir = '/dartfs-hpc/scratch/f005d7d/what_where_analysis/'
processed_path = os.path.join(root_dir, 'processed/')

with open(os.path.join(processed_path, 'all_sess_regression_info.pkl'), 'rb') as f:
    all_sess_regression_info = pickle.load(f)

# %%
all_sess_exp_var = np.concatenate(all_sess_regression_info['exp_vars'], axis=1)

# %%
fig, axes = plt.subplots(1,1)

axes.plot(all_sess_exp_var.mean(1)[:,1:3])
axes.set_title('Block type')
axes.set_xlabel('Time')
axes.set_ylabel('$\\eta^2$')
sns.despine()

# %%
fig, axes = plt.subplots(1,4, sharey=True, sharex=True, figsize=(2.4*4, 2.4))

axes[0].plot(all_sess_exp_var.mean(1)[:,3:5])
axes[0].set_title('Stim config')
axes[1].plot(all_sess_exp_var.mean(1)[:,5:7])
axes[1].set_title('Img chosen')
axes[2].plot(all_sess_exp_var.mean(1)[:,7:9])
axes[2].set_title('Loc chosen')
axes[3].plot(all_sess_exp_var.mean(1)[:,9:11])
axes[3].set_title('Rwd')


# axes[0].set_ylim([-0.001, 0.05])
fig.supxlabel('Time')
fig.supylabel('$\\eta^2$')
fig.suptitle('Current trial information')

sns.despine()

fig.tight_layout()

# %%
fig, axes = plt.subplots(1,3, sharey=True, sharex=True, figsize=(2.4*3, 2.4))

axes[0].plot(all_sess_exp_var.mean(1)[:,11:13])
axes[0].set_title('Img chosen')
axes[1].plot(all_sess_exp_var.mean(1)[:,13:15])
axes[1].set_title('Loc chosen')
axes[2].plot(all_sess_exp_var.mean(1)[:,15:17])
axes[2].set_title('Rwd')


# axes[0].set_ylim([-0.001, 0.05])
fig.supxlabel('Time')
fig.supylabel('$\\eta^2$')
fig.suptitle('Previous trial information')

sns.despine()

fig.tight_layout()

# %%
fig, axes = plt.subplots(1,5, sharey=True, sharex=True, figsize=(2.4*5, 2.4))

axes[0].plot(all_sess_exp_var.mean(1)[:,19:21])
axes[0].set_title('Rewarded img')
axes[1].plot(all_sess_exp_var.mean(1)[:,17:19])
axes[1].set_title('Rewarded loc')
axes[2].plot(all_sess_exp_var.mean(1)[:,21:23])
axes[2].set_title('Loc of img chosen')
axes[3].plot(all_sess_exp_var.mean(1)[:,23:25])
axes[3].set_title('Rwd X config')
axes[4].plot(all_sess_exp_var.mean(1)[:,25:27])
axes[4].set_title('Loc of img rewarded')


# axes[0].set_ylim([-0.001, 0.05])
fig.supxlabel('Time')
fig.supylabel('$\\eta^2$')
fig.suptitle('Interaction effects')

sns.despine()

fig.tight_layout()
