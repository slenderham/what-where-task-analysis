# %%
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import glob
import h5py
import re
from scipy.ndimage import gaussian_filter
from tqdm import tqdm
import scipy.io as sio
from matplotlib import pyplot as plt
from joblib import Parallel, delayed
import pickle
import os


monkey_names = ["W", "V"]
# aligned_events = ["StimOnset", "Choice", "RewFeedback"]
aligned_events = ["StimOnset"]

root_dir = '/Users/f005d7d/Documents/Attn_MdPRL/what-where-task/'
# root_dir = '/dartfs-hpc/scratch/f005d7d/what_where_analysis/'

bhv_path = os.path.join(root_dir, 'Behavior/')
processed_path = os.path.join(root_dir, 'processed/')
neural_path = os.path.join(root_dir, 'RasterVec_binSize_10ms/')

binsize = 0.01
gauss_SD = 0.02/binsize

all_sess_regression_info = {
    'aligned_event': [],
    'monkey_name': [],
    'area_name': [],
    'sess_date': [],
    'betas': [],
    'exp_vars': [],
    'pvals': []
}

# 12 regressors, separate by blocks
regressor_names = ['type', 'block',
                    'S_curr', 'C_what_curr', 'C_where_curr', 'R_curr',
                    'C_what_prev', 'C_where_prev', 'R_prev',
                    'RXC_where', 'RXC_what',
                    'SXC_what', 'RXS', 'RXSXC_what']

regressor_expr = ['C(block_type, Sum)/C(block_id, Sum)',
                       '(C(block_type, Sum)/C(block_id, Sum))*(C_what_curr:C_where_curr)',
                       '(C(block_type, Sum)/C(block_id, Sum))*C_what_curr',
                       'C(block_type, Sum)*C_where_curr', 'C(block_type, Sum)*R_curr',
                       '(C(block_type, Sum)/C(block_id, Sum))*C_what_prev',
                       'C(block_type, Sum)*C_where_prev', 'C(block_type, Sum)*R_prev',
                       'C(block_type, Sum)*(R_prev:C_where_prev)',
                       '(C(block_type, Sum)/C(block_id, Sum))*(R_prev:C_what_prev)',
                       'C(block_type, Sum)*(C_what_curr:C_where_curr:C_what_prev)',
                       '(C(block_type, Sum)/C(block_id, Sum))*(R_prev:C_what_curr:C_where_curr)',
                       'C(block_type, Sum)*(R_prev:C_what_curr:C_where_curr:C_what_prev)']

var_names_in_table = ['C_what_curr', 'C_where_curr', 'R_curr', 'block_type', 'block_id',
                        'C_what_prev', 'C_where_prev', 'R_prev']

formula = 'fr~'+'+'.join(regressor_expr)

# %%
for event_idx, aligned_event in enumerate(aligned_events):
    for monkey_idx, monkey_name in enumerate(monkey_names):
        files = glob.glob(
            f'{neural_path}/{aligned_event}/RastVect-{monkey_name}*-binsize10ms-align2{aligned_event}.mat')
        for sess_idx in range(len(files)):
            filename = files[sess_idx]

            curr_sess_neural = h5py.File(filename)
            sess_date = re.search(re.compile(
                f'RastVect-{monkey_name}(\\d*)-binsize10ms-align2{aligned_event}.mat'), filename).groups()[0]

            neural_data = gaussian_filter(curr_sess_neural['aligned2event'], gauss_SD, mode='constant', axes=2)

            bhv_filename = bhv_path+'SPKcounts_'+monkey_name+sess_date+'cue_MW_250X250ms.mat'
            curr_sess_bhv = sio.loadmat(
                bhv_path+'SPKcounts_'+monkey_name+sess_date+'cue_MW_250X250ms.mat')
            task_info = curr_sess_bhv['Y']

            # only keep chosen image, chosen loc, reward, block type, block id
            task_info = task_info[:, [0, 1, 2, 9, 7]].astype(float)

            trial_mask = task_info[:, 4] <= 24
            task_info = task_info[trial_mask]
            neural_data = neural_data[trial_mask]
            area_idx = curr_sess_neural['vectorInfo']['Array'][:].squeeze()
            # neural_data = neural_data[:,:,window_start:]

            neuron_mask = np.nonzero(np.min(neural_data.sum(0), 1))[0]
            neural_data = neural_data[:, neuron_mask, :]
            area_idx = area_idx[neuron_mask].squeeze()

            num_trials, num_units, num_timesteps = neural_data.shape

            print("--------------------------------------------------------------------")
            print("aligned to: " + aligned_event + ", monkey: " +
                    monkey_name + ", session: " + sess_date + ", #trials=" + str(num_trials))

            task_info[:, :3] = task_info[:, :3]*2-1
            task_info[:, 3] = task_info[:, 3]*2-3
            task_info[:, 4] = task_info[:, 4] % 12

            # make the time-lagged part of the design
            task_info_prev = np.concatenate([np.array([[0, 0, 0]]), task_info[:-1, :3]], axis=0)

            # put together design matrix
            # C_what_curr, C_where_curr, R_curr, block_id, block_type
            # C_what_prev, C_where_prev, R_curr
            X = np.concatenate([task_info, task_info_prev], axis=1)

            num_betas = 158
            num_exp_vars = 32

            all_units_beta = np.ones((num_timesteps, num_units, num_betas))*np.nan
            all_units_exp_var = np.ones((num_timesteps, num_units, num_exp_vars))*np.nan
            all_units_pvals = np.ones((num_timesteps, num_units, num_exp_vars))*np.nan

            for unit_idx in tqdm(range(num_units)):
                def run_linreg_anova(time_idx):
                    curr_unit_time_fr = neural_data[:, unit_idx, time_idx]
                    tbl = pd.DataFrame(np.concatenate([curr_unit_time_fr[:, None], X], axis=1),
                                        columns=['fr']+var_names_in_table)
                    
                    
                    # fit linear model
                    mdl = smf.ols(formula, tbl).fit()
                    
                    # calculate anova
                    anova_mdl = sm.stats.anova_lm(mdl, typ=3)

                    # calculate effect size for anova
                    ms_error = anova_mdl.loc[:,'sum_sq'].iloc[-1]/anova_mdl.loc[:,'sum_sq'].iloc[-1]
                    omega_sq = (anova_mdl.loc[:,'sum_sq'].iloc[:-1]-anova_mdl.loc[:,'sum_sq'].iloc[:-1]*ms_error)/ \
                                    (anova_mdl.loc[:,'sum_sq'].sum()+ms_error)

                    pvals = anova_mdl.loc[:,'PR(>F)'].iloc[:-1].to_numpy().squeeze()
                    print(anova_mdl)

                    return [mdl.params, omega_sq, pvals]

                linreg_anova_results = Parallel(n_jobs=1)(
                    delayed(run_linreg_anova)(time_idx) for time_idx in range(num_timesteps))

                all_units_beta[:, unit_idx, :] = np.stack([curr_time_results[0] for curr_time_results in linreg_anova_results])
                all_units_exp_var[:, unit_idx, :] = np.stack([curr_time_results[1] for curr_time_results in linreg_anova_results])
                all_units_pvals[:, unit_idx, :] = np.stack([curr_time_results[2] for curr_time_results in linreg_anova_results])

            all_sess_regression_info['neural_data'].append(neural_data)
            all_sess_regression_info['monkey_name'].append(monkey_name)
            all_sess_regression_info['aligned_event'].append(aligned_event)
            all_sess_regression_info['area_name'].append(area_idx)
            all_sess_regression_info['sess_date'].append(sess_date)
            all_sess_regression_info['betas'].append(all_units_beta)
            all_sess_regression_info['exp_vars'].append(all_units_exp_var)
            all_sess_regression_info['pvals'].append(all_units_pvals)

            with open(os.path.join(processed_path, 'all_sess_regression_info.pkl'), 'wb') as f:
                pickle.dump(all_sess_regression_info, f)
# Out:
# --------------------------------------------------------------------
# aligned to: StimOnset, monkey: W, session: 20160122, #trials=1923
#   0%|          | 0/564 [00:00<?, ?it/s]
#                                                           sum_sq      df  \
# Intercept                                           4.397774e-04     1.0
# C(block_type, Sum)                                  2.044736e-04     1.0
# C(block_type, Sum):C(block_id, Sum)                 2.059998e-03    22.0
# C_what_curr:C_where_curr                            3.465585e-04     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         1.437119e-04     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  1.196164e-03    22.0
# C_what_curr                                         4.477640e-06     1.0
# C(block_type, Sum):C_what_curr                      4.984104e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     8.945232e-04    22.0
# C_where_curr                                        1.022752e-04     1.0
# C(block_type, Sum):C_where_curr                     4.107674e-05     1.0
# R_curr                                              1.254763e-04     1.0
# C(block_type, Sum):R_curr                           1.578183e-04     1.0
# C_what_prev                                         4.178887e-08     1.0
# C(block_type, Sum):C_what_prev                      6.055480e-06     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     7.240586e-04    22.0
# C_where_prev                                        1.768164e-04     1.0
# C(block_type, Sum):C_where_prev                     1.208268e-04     1.0
# R_prev                                              3.048918e-04     1.0
# C(block_type, Sum):R_prev                           1.220101e-04     1.0
# R_prev:C_where_prev                                 2.344344e-04     1.0
# C(block_type, Sum):R_prev:C_where_prev              2.085090e-04     1.0
# R_prev:C_what_prev                                  4.282588e-05     1.0
# C(block_type, Sum):R_prev:C_what_prev               8.675441e-05     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  2.421362e-03    22.0
# C_what_curr:C_where_curr:C_what_prev                1.074307e-04     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  1.091461e-04     1.0
# R_prev:C_what_curr:C_where_curr                     5.225029e-04     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  2.768984e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  2.364726e-03    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         4.175973e-06     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  2.111748e-05     1.0
# Residual                                            1.153652e-01  1765.0
#
#                                                            F    PR(>F)
# Intercept                                           6.728262  0.009568
# C(block_type, Sum)                                  3.128291  0.077117
# C(block_type, Sum):C(block_id, Sum)                 1.432564  0.087934
# C_what_curr:C_where_curr                            5.302082  0.021416
# C(block_type, Sum):C_what_curr:C_where_curr         2.198684  0.138307
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  0.831837  0.687511
# C_what_curr                                         0.068505  0.793557
# C(block_type, Sum):C_what_curr                      0.762530  0.382657
# C(block_type, Sum):C(block_id, Sum):C_what_curr     0.622070  0.911456
# C_where_curr                                        1.564734  0.211139
# C(block_type, Sum):C_where_curr                     0.628443  0.428034
# R_curr                                              1.919693  0.166066
# C(block_type, Sum):R_curr                           2.414501  0.120396
# C_what_prev                                         0.000639  0.979830
# C(block_type, Sum):C_what_prev                      0.092644  0.760878
# C(block_type, Sum):C(block_id, Sum):C_what_prev     0.503525  0.973213
# C_where_prev                                        2.705157  0.100202
# C(block_type, Sum):C_where_prev                     1.848558  0.174125
# R_prev                                              4.664614  0.030925
# C(block_type, Sum):R_prev                           1.866662  0.172032
# R_prev:C_where_prev                                 3.586669  0.058408
# C(block_type, Sum):R_prev:C_where_prev              3.190030  0.074260
# R_prev:C_what_prev                                  0.655204  0.418367
# C(block_type, Sum):R_prev:C_what_prev               1.327277  0.249446
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  1.683864  0.024452
# C_what_curr:C_where_curr:C_what_prev                1.643609  0.199999
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  1.669853  0.196447
# R_prev:C_what_curr:C_where_curr                     7.993900  0.004746
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  4.236337  0.039714
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  1.644478  0.030254
# R_prev:C_what_curr:C_where_curr:C_what_prev         0.063889  0.800481
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  0.323082  0.569834
# Residual                                                 NaN       NaN
#                                                           sum_sq      df  \
# Intercept                                           8.840397e-04     1.0
# C(block_type, Sum)                                  2.442705e-04     1.0
# C(block_type, Sum):C(block_id, Sum)                 2.903478e-03    22.0
# C_what_curr:C_where_curr                            7.329959e-04     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         1.731100e-04     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  1.965279e-03    22.0
# C_what_curr                                         3.881426e-08     1.0
# C(block_type, Sum):C_what_curr                      1.050260e-04     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     1.416037e-03    22.0
# C_where_curr                                        2.046073e-04     1.0
# C(block_type, Sum):C_where_curr                     5.655175e-05     1.0
# R_curr                                              1.738390e-04     1.0
# C(block_type, Sum):R_curr                           2.152583e-04     1.0
# C_what_prev                                         6.984669e-06     1.0
# C(block_type, Sum):C_what_prev                      2.006983e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     1.281470e-03    22.0
# C_where_prev                                        3.000443e-04     1.0
# C(block_type, Sum):C_where_prev                     1.849013e-04     1.0
# R_prev                                              6.692456e-04     1.0
# C(block_type, Sum):R_prev                           1.450389e-04     1.0
# R_prev:C_where_prev                                 3.473903e-04     1.0
# C(block_type, Sum):R_prev:C_where_prev              3.025517e-04     1.0
# R_prev:C_what_prev                                  5.879523e-05     1.0
# C(block_type, Sum):R_prev:C_what_prev               1.291954e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  3.757759e-03    22.0
# C_what_curr:C_where_curr:C_what_prev                1.851265e-04     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  1.522384e-04     1.0
# R_prev:C_what_curr:C_where_curr                     9.882580e-04     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  3.263551e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  3.454581e-03    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         9.784462e-06     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  3.375863e-05     1.0
# Residual                                            1.856594e-01  1765.0
#
#                                                            F    PR(>F)
# Intercept                                           8.404259  0.003790
# C(block_type, Sum)                                  2.322196  0.127719
# C(block_type, Sum):C(block_id, Sum)                 1.254653  0.191305
# C_what_curr:C_where_curr                            6.968338  0.008370
# C(block_type, Sum):C_what_curr:C_where_curr         1.645697  0.199714
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  0.849238  0.664377
# C_what_curr                                         0.000369  0.984676
# C(block_type, Sum):C_what_curr                      0.998446  0.317824
# C(block_type, Sum):C(block_id, Sum):C_what_curr     0.611899  0.918698
# C_where_curr                                        1.945131  0.163288
# C(block_type, Sum):C_where_curr                     0.537618  0.463519
# R_curr                                              1.652627  0.198770
# C(block_type, Sum):R_curr                           2.046386  0.152745
# C_what_prev                                         0.066401  0.796681
# C(block_type, Sum):C_what_prev                      0.190797  0.662308
# C(block_type, Sum):C(block_id, Sum):C_what_prev     0.553750  0.952904
# C_where_prev                                        2.852418  0.091413
# C(block_type, Sum):C_where_prev                     1.757792  0.185072
# R_prev                                              6.362287  0.011744
# C(block_type, Sum):R_prev                           1.378835  0.240458
# R_prev:C_where_prev                                 3.302519  0.069343
# C(block_type, Sum):R_prev:C_where_prev              2.876255  0.090071
# R_prev:C_what_prev                                  0.558946  0.454785
# C(block_type, Sum):R_prev:C_what_prev               1.228216  0.267905
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  1.623805  0.033772
# C_what_curr:C_where_curr:C_what_prev                1.759933  0.184804
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  1.447277  0.229127
# R_prev:C_what_curr:C_where_curr                     9.395027  0.002209
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  3.102545  0.078343
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  1.492796  0.065870
# R_prev:C_what_curr:C_where_curr:C_what_prev         0.093017  0.760411
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  0.320932  0.571120
# Residual                                                 NaN       NaN
#                                                       sum_sq      df  \
# Intercept                                           0.001318     1.0
# C(block_type, Sum)                                  0.000148     1.0
# C(block_type, Sum):C(block_id, Sum)                 0.002842    22.0
# C_what_curr:C_where_curr                            0.001117     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         0.000101     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  0.002482    22.0
# C_what_curr                                         0.000012     1.0
# C(block_type, Sum):C_what_curr                      0.000157     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     0.001725    22.0
# C_where_curr                                        0.000263     1.0
# C(block_type, Sum):C_where_curr                     0.000045     1.0
# R_curr                                              0.000134     1.0
# C(block_type, Sum):R_curr                           0.000134     1.0
# C_what_prev                                         0.000039     1.0
# C(block_type, Sum):C_what_prev                      0.000070     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     0.001946    22.0
# C_where_prev                                        0.000311     1.0
# C(block_type, Sum):C_where_prev                     0.000173     1.0
# R_prev                                              0.001085     1.0
# C(block_type, Sum):R_prev                           0.000078     1.0
# R_prev:C_where_prev                                 0.000319     1.0
# C(block_type, Sum):R_prev:C_where_prev              0.000271     1.0
# R_prev:C_what_prev                                  0.000046     1.0
# C(block_type, Sum):R_prev:C_what_prev               0.000082     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.004513    22.0
# C_what_curr:C_where_curr:C_what_prev                0.000214     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  0.000092     1.0
# R_prev:C_what_curr:C_where_curr                     0.001340     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  0.000182     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.003681    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         0.000018     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  0.000012     1.0
# Residual                                            0.217900  1765.0
#
#                                                             F    PR(>F)
# Intercept                                           10.673725  0.001108
# C(block_type, Sum)                                   1.202539  0.272964
# C(block_type, Sum):C(block_id, Sum)                  1.046242  0.401853
# C_what_curr:C_where_curr                             9.051800  0.002662
# C(block_type, Sum):C_what_curr:C_where_curr          0.816994  0.366184
# C(block_type, Sum):C(block_id, Sum):C_what_curr...   0.914004  0.576319
# C_what_curr                                          0.096425  0.756199
# C(block_type, Sum):C_what_curr                       1.273878  0.259194
# C(block_type, Sum):C(block_id, Sum):C_what_curr      0.635102  0.901623
# C_where_curr                                         2.126750  0.144925
# C(block_type, Sum):C_where_curr                      0.362300  0.547309
# R_curr                                               1.087313  0.297210
# C(block_type, Sum):R_curr                            1.081859  0.298424
# C_what_prev                                          0.317020  0.573476
# C(block_type, Sum):C_what_prev                       0.568665  0.450891
# C(block_type, Sum):C(block_id, Sum):C_what_prev      0.716423  0.826648
# C_where_prev                                         2.517426  0.112773
# C(block_type, Sum):C_where_prev                      1.399325  0.236996
# R_prev                                               8.786189  0.003076
# C(block_type, Sum):R_prev                            0.628658  0.427955
# R_prev:C_where_prev                                  2.580928  0.108337
# C(block_type, Sum):R_prev:C_where_prev               2.195993  0.138549
# R_prev:C_what_prev                                   0.371827  0.542088
# C(block_type, Sum):R_prev:C_what_prev                0.666318  0.414449
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.661533  0.027604
# C_what_curr:C_where_curr:C_what_prev                 1.732395  0.188276
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...   0.748277  0.387140
# R_prev:C_what_curr:C_where_curr                     10.850114  0.001007
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr   1.471219  0.225316
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.355208  0.125108
# R_prev:C_what_curr:C_where_curr:C_what_prev          0.143876  0.704504
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...   0.099285  0.752726
# Residual                                                  NaN       NaN
#                                                       sum_sq      df  \
# Intercept                                           0.001540     1.0
# C(block_type, Sum)                                  0.000032     1.0
# C(block_type, Sum):C(block_id, Sum)                 0.002378    22.0
# C_what_curr:C_where_curr                            0.001249     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         0.000014     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  0.002781    22.0
# C_what_curr                                         0.000048     1.0
# C(block_type, Sum):C_what_curr                      0.000166     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     0.001907    22.0
# C_where_curr                                        0.000210     1.0
# C(block_type, Sum):C_where_curr                     0.000019     1.0
# R_curr                                              0.000046     1.0
# C(block_type, Sum):R_curr                           0.000010     1.0
# C_what_prev                                         0.000087     1.0
# C(block_type, Sum):C_what_prev                      0.000194     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     0.002824    22.0
# C_where_prev                                        0.000202     1.0
# C(block_type, Sum):C_where_prev                     0.000104     1.0
# R_prev                                              0.001355     1.0
# C(block_type, Sum):R_prev                           0.000007     1.0
# R_prev:C_where_prev                                 0.000197     1.0
# C(block_type, Sum):R_prev:C_where_prev              0.000158     1.0
# R_prev:C_what_prev                                  0.000018     1.0
# C(block_type, Sum):R_prev:C_what_prev               0.000003     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.004871    22.0
# C_what_curr:C_where_curr:C_what_prev                0.000184     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  0.000005     1.0
# R_prev:C_what_curr:C_where_curr                     0.001354     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  0.000021     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.003548    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         0.000033     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  0.000010     1.0
# Residual                                            0.214553  1765.0
#
#                                                             F    PR(>F)
# Intercept                                           12.666846  0.000382
# C(block_type, Sum)                                   0.265593  0.606368
# C(block_type, Sum):C(block_id, Sum)                  0.889078  0.610410
# C_what_curr:C_where_curr                            10.273871  0.001373
# C(block_type, Sum):C_what_curr:C_where_curr          0.117199  0.732133
# C(block_type, Sum):C(block_id, Sum):C_what_curr...   1.039855  0.409766
# C_what_curr                                          0.395259  0.529629
# C(block_type, Sum):C_what_curr                       1.366204  0.242623
# C(block_type, Sum):C(block_id, Sum):C_what_curr      0.713022  0.830228
# C_where_curr                                         1.725267  0.189187
# C(block_type, Sum):C_where_curr                      0.159766  0.689420
# R_curr                                               0.377341  0.539109
# C(block_type, Sum):R_curr                            0.081247  0.775648
# C_what_prev                                          0.719785  0.396330
# C(block_type, Sum):C_what_prev                       1.598439  0.206291
# C(block_type, Sum):C(block_id, Sum):C_what_prev      1.056147  0.389724
# C_where_prev                                         1.663743  0.197268
# C(block_type, Sum):C_where_prev                      0.857010  0.354703
# R_prev                                              11.150869  0.000857
# C(block_type, Sum):R_prev                            0.054829  0.814891
# R_prev:C_where_prev                                  1.624186  0.202677
# C(block_type, Sum):R_prev:C_where_prev               1.297789  0.254772
# R_prev:C_what_prev                                   0.148466  0.700052
# C(block_type, Sum):R_prev:C_what_prev                0.025168  0.873967
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.821334  0.011271
# C_what_curr:C_where_curr:C_what_prev                 1.515066  0.218532
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...   0.044263  0.833390
# R_prev:C_what_curr:C_where_curr                     11.138988  0.000863
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr   0.169537  0.680574
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.326845  0.141594
# R_prev:C_what_curr:C_where_curr:C_what_prev          0.269658  0.603626
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...   0.081641  0.775119
# Residual                                                  NaN       NaN
#                                                           sum_sq      df  \
# Intercept                                           1.456384e-03     1.0
# C(block_type, Sum)                                  2.179955e-10     1.0
# C(block_type, Sum):C(block_id, Sum)                 2.181288e-03    22.0
# C_what_curr:C_where_curr                            9.994426e-04     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         7.261297e-06     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  2.898372e-03    22.0
# C_what_curr                                         6.571327e-05     1.0
# C(block_type, Sum):C_what_curr                      1.186576e-04     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     1.938337e-03    22.0
# C_where_curr                                        9.871959e-05     1.0
# C(block_type, Sum):C_where_curr                     4.573519e-06     1.0
# R_curr                                              6.537906e-07     1.0
# C(block_type, Sum):R_curr                           4.973385e-05     1.0
# C_what_prev                                         9.791247e-05     1.0
# C(block_type, Sum):C_what_prev                      3.602026e-04     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     3.499395e-03    22.0
# C_where_prev                                        9.953304e-05     1.0
# C(block_type, Sum):C_where_prev                     5.234820e-05     1.0
# R_prev                                              1.332689e-03     1.0
# C(block_type, Sum):R_prev                           9.596453e-06     1.0
# R_prev:C_where_prev                                 1.103952e-04     1.0
# C(block_type, Sum):R_prev:C_where_prev              7.230533e-05     1.0
# R_prev:C_what_prev                                  1.323100e-06     1.0
# C(block_type, Sum):R_prev:C_what_prev               5.934471e-05     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  4.859348e-03    22.0
# C_what_curr:C_where_curr:C_what_prev                1.411558e-04     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  3.326022e-05     1.0
# R_prev:C_what_curr:C_where_curr                     1.019808e-03     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  1.960677e-05     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  3.591291e-03    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         6.212525e-05     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  1.226889e-04     1.0
# Residual                                            1.967724e-01  1765.0
#
#                                                             F    PR(>F)
# Intercept                                           13.063410  0.000310
# C(block_type, Sum)                                   0.000002  0.998884
# C(block_type, Sum):C(block_id, Sum)                  0.889346  0.610043
# C_what_curr:C_where_curr                             8.964754  0.002791
# C(block_type, Sum):C_what_curr:C_where_curr          0.065132  0.798591
# C(block_type, Sum):C(block_id, Sum):C_what_curr...   1.181713  0.253664
# C_what_curr                                          0.589432  0.442742
# C(block_type, Sum):C_what_curr                       1.064329  0.302371
# C(block_type, Sum):C(block_id, Sum):C_what_curr      0.790291  0.740959
# C_where_curr                                         0.885490  0.346831
# C(block_type, Sum):C_where_curr                      0.041023  0.839516
# R_curr                                               0.005864  0.938967
# C(block_type, Sum):R_curr                            0.446100  0.504280
# C_what_prev                                          0.878251  0.348809
# C(block_type, Sum):C_what_prev                       3.230928  0.072431
# C(block_type, Sum):C(block_id, Sum):C_what_prev      1.426760  0.090358
# C_where_prev                                         0.892787  0.344853
# C(block_type, Sum):C_where_prev                      0.469550  0.493284
# R_prev                                              11.953888  0.000558
# C(block_type, Sum):R_prev                            0.086078  0.769258
# R_prev:C_where_prev                                  0.990218  0.319826
# C(block_type, Sum):R_prev:C_where_prev               0.648561  0.420736
# R_prev:C_what_prev                                   0.011868  0.913263
# C(block_type, Sum):R_prev:C_what_prev                0.532307  0.465735
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.981234  0.004333
# C_what_curr:C_where_curr:C_what_prev                 1.266133  0.260646
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...   0.298336  0.584997
# R_prev:C_what_curr:C_where_curr                      9.147430  0.002527
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr   0.175868  0.675000
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.464227  0.075658
# R_prev:C_what_curr:C_where_curr:C_what_prev          0.557248  0.455471
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...   1.100489  0.294302
# Residual                                                  NaN       NaN
#                                                       sum_sq      df  \
# Intercept                                           0.001125     1.0
# C(block_type, Sum)                                  0.000004     1.0
# C(block_type, Sum):C(block_id, Sum)                 0.002022    22.0
# C_what_curr:C_where_curr                            0.000523     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         0.000051     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  0.002674    22.0
# C_what_curr                                         0.000044     1.0
# C(block_type, Sum):C_what_curr                      0.000054     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     0.001603    22.0
# C_where_curr                                        0.000026     1.0
# C(block_type, Sum):C_where_curr                     0.000001     1.0
# R_curr                                              0.000018     1.0
# C(block_type, Sum):R_curr                           0.000205     1.0
# C_what_prev                                         0.000053     1.0
# C(block_type, Sum):C_what_prev                      0.000429     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     0.003247    22.0
# C_where_prev                                        0.000061     1.0
# C(block_type, Sum):C_where_prev                     0.000039     1.0
# R_prev                                              0.001029     1.0
# C(block_type, Sum):R_prev                           0.000029     1.0
# R_prev:C_where_prev                                 0.000082     1.0
# C(block_type, Sum):R_prev:C_where_prev              0.000039     1.0
# R_prev:C_what_prev                                  0.000003     1.0
# C(block_type, Sum):R_prev:C_what_prev               0.000216     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.004166    22.0
# C_what_curr:C_where_curr:C_what_prev                0.000114     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  0.000098     1.0
# R_prev:C_what_curr:C_where_curr                     0.000523     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  0.000103     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.003356    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         0.000096     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  0.000238     1.0
# Residual                                            0.162911  1765.0
#
#                                                             F    PR(>F)
# Intercept                                           12.184362  0.000494
# C(block_type, Sum)                                   0.042933  0.835875
# C(block_type, Sum):C(block_id, Sum)                  0.995571  0.466420
# C_what_curr:C_where_curr                             5.664732  0.017415
# C(block_type, Sum):C_what_curr:C_where_curr          0.547694  0.459360
# C(block_type, Sum):C(block_id, Sum):C_what_curr...   1.316705  0.147890
# C_what_curr                                          0.475816  0.490414
# C(block_type, Sum):C_what_curr                       0.582238  0.445539
# C(block_type, Sum):C(block_id, Sum):C_what_curr      0.789577  0.741850
# C_where_curr                                         0.276832  0.598852
# C(block_type, Sum):C_where_curr                      0.012245  0.911900
# R_curr                                               0.192218  0.661131
# C(block_type, Sum):R_curr                            2.219208  0.136482
# C_what_prev                                          0.569619  0.450511
# C(block_type, Sum):C_what_prev                       4.642589  0.031323
# C(block_type, Sum):C(block_id, Sum):C_what_prev      1.598863  0.038505
# C_where_prev                                         0.658240  0.417291
# C(block_type, Sum):C_where_prev                      0.417833  0.518105
# R_prev                                              11.145520  0.000860
# C(block_type, Sum):R_prev                            0.309444  0.578092
# R_prev:C_where_prev                                  0.884413  0.347124
# C(block_type, Sum):R_prev:C_where_prev               0.420374  0.516835
# R_prev:C_what_prev                                   0.037594  0.846283
# C(block_type, Sum):R_prev:C_what_prev                2.343571  0.125980
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   2.051397  0.002801
# C_what_curr:C_where_curr:C_what_prev                 1.231531  0.267261
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...   1.066999  0.301766
# R_prev:C_what_curr:C_where_curr                      5.661667  0.017445
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr   1.117486  0.290605
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.652854  0.028925
# R_prev:C_what_curr:C_where_curr:C_what_prev          1.037546  0.308532
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...   2.576105  0.108667
# Residual                                                  NaN       NaN
#                                                           sum_sq      df  \
# Intercept                                           7.342998e-04     1.0
# C(block_type, Sum)                                  1.069763e-07     1.0
# C(block_type, Sum):C(block_id, Sum)                 1.523003e-03    22.0
# C_what_curr:C_where_curr                            1.376423e-04     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         7.979192e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  2.193572e-03    22.0
# C_what_curr                                         1.465435e-05     1.0
# C(block_type, Sum):C_what_curr                      1.623975e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     1.054205e-03    22.0
# C_where_curr                                        3.968254e-06     1.0
# C(block_type, Sum):C_where_curr                     2.109803e-06     1.0
# R_curr                                              4.975251e-05     1.0
# C(block_type, Sum):R_curr                           2.542055e-04     1.0
# C_what_prev                                         9.055361e-06     1.0
# C(block_type, Sum):C_what_prev                      3.257401e-04     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     2.261477e-03    22.0
# C_where_prev                                        5.913086e-05     1.0
# C(block_type, Sum):C_where_prev                     4.811275e-05     1.0
# R_prev                                              6.322661e-04     1.0
# C(block_type, Sum):R_prev                           1.688598e-05     1.0
# R_prev:C_where_prev                                 6.424150e-05     1.0
# C(block_type, Sum):R_prev:C_where_prev              2.557448e-05     1.0
# R_prev:C_what_prev                                  2.089583e-05     1.0
# C(block_type, Sum):R_prev:C_what_prev               2.733459e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  3.042364e-03    22.0
# C_what_curr:C_where_curr:C_what_prev                9.903317e-05     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  7.292446e-05     1.0
# R_prev:C_what_curr:C_where_curr                     1.279078e-04     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  1.534105e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  2.473975e-03    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         9.959128e-05     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  2.078072e-04     1.0
# Residual                                            1.162505e-01  1765.0
#
#                                                             F    PR(>F)
# Intercept                                           11.148680  0.000858
# C(block_type, Sum)                                   0.001624  0.967857
# C(block_type, Sum):C(block_id, Sum)                  1.051061  0.395930
# C_what_curr:C_where_curr                             2.089787  0.148464
# C(block_type, Sum):C_what_curr:C_where_curr          1.211460  0.271193
# C(block_type, Sum):C(block_id, Sum):C_what_curr...   1.513837  0.059379
# C_what_curr                                          0.222493  0.637205
# C(block_type, Sum):C_what_curr                       0.246564  0.619567
# C(block_type, Sum):C(block_id, Sum):C_what_curr      0.727533  0.814709
# C_where_curr                                         0.060249  0.806131
# C(block_type, Sum):C_where_curr                      0.032033  0.857977
# R_curr                                               0.755379  0.384897
# C(block_type, Sum):R_curr                            3.859535  0.049621
# C_what_prev                                          0.137485  0.710839
# C(block_type, Sum):C_what_prev                       4.945625  0.026283
# C(block_type, Sum):C(block_id, Sum):C_what_prev      1.560700  0.046895
# C_where_prev                                         0.897768  0.343511
# C(block_type, Sum):C_where_prev                      0.730483  0.392843
# R_prev                                               9.599529  0.001977
# C(block_type, Sum):R_prev                            0.256375  0.612685
# R_prev:C_where_prev                                  0.975362  0.323482
# C(block_type, Sum):R_prev:C_where_prev               0.388291  0.533280
# R_prev:C_what_prev                                   0.317256  0.573333
# C(block_type, Sum):R_prev:C_what_prev                4.150139  0.041780
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   2.099610  0.002064
# C_what_curr:C_where_curr:C_what_prev                 1.503594  0.220283
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...   1.107193  0.292837
# R_prev:C_what_curr:C_where_curr                      1.941990  0.163628
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr   2.329191  0.127147
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.707350  0.021495
# R_prev:C_what_curr:C_where_curr:C_what_prev          1.512068  0.218988
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...   3.155081  0.075863
# Residual                                                  NaN       NaN
#                                                           sum_sq      df  \
# Intercept                                           4.796156e-04     1.0
# C(block_type, Sum)                                  1.002612e-05     1.0
# C(block_type, Sum):C(block_id, Sum)                 9.867766e-04    22.0
# C_what_curr:C_where_curr                            2.642771e-06     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         7.148389e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  1.721380e-03    22.0
# C_what_curr                                         7.481815e-07     1.0
# C(block_type, Sum):C_what_curr                      8.506891e-06     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     6.729275e-04    22.0
# C_where_curr                                        1.103534e-06     1.0
# C(block_type, Sum):C_where_curr                     9.786128e-06     1.0
# R_curr                                              5.286157e-05     1.0
# C(block_type, Sum):R_curr                           1.502036e-04     1.0
# C_what_prev                                         1.099267e-07     1.0
# C(block_type, Sum):C_what_prev                      1.518073e-04     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     1.385349e-03    22.0
# C_where_prev                                        5.205165e-05     1.0
# C(block_type, Sum):C_where_prev                     5.953548e-05     1.0
# R_prev                                              3.527583e-04     1.0
# C(block_type, Sum):R_prev                           2.520469e-06     1.0
# R_prev:C_where_prev                                 1.723871e-05     1.0
# C(block_type, Sum):R_prev:C_where_prev              7.038577e-06     1.0
# R_prev:C_what_prev                                  4.602751e-05     1.0
# C(block_type, Sum):R_prev:C_what_prev               1.902096e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  2.129590e-03    22.0
# C_what_curr:C_where_curr:C_what_prev                9.154582e-05     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  1.558336e-05     1.0
# R_prev:C_what_curr:C_where_curr                     3.053734e-07     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  1.623986e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  1.466535e-03    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         6.571010e-05     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  1.234621e-04     1.0
# Residual                                            7.933351e-02  1765.0
#
#                                                             F    PR(>F)
# Intercept                                           10.670415  0.001110
# C(block_type, Sum)                                   0.223060  0.636777
# C(block_type, Sum):C(block_id, Sum)                  0.997893  0.463379
# C_what_curr:C_where_curr                             0.058796  0.808437
# C(block_type, Sum):C_what_curr:C_where_curr          1.590363  0.207441
# C(block_type, Sum):C(block_id, Sum):C_what_curr...   1.740772  0.017847
# C_what_curr                                          0.016645  0.897359
# C(block_type, Sum):C_what_curr                       0.189260  0.663586
# C(block_type, Sum):C(block_id, Sum):C_what_curr      0.680509  0.862566
# C_where_curr                                         0.024551  0.875508
# C(block_type, Sum):C_where_curr                      0.217720  0.640840
# R_curr                                               1.176056  0.278308
# C(block_type, Sum):R_curr                            3.341708  0.067713
# C_what_prev                                          0.002446  0.960564
# C(block_type, Sum):C_what_prev                       3.377387  0.066265
# C(block_type, Sum):C(block_id, Sum):C_what_prev      1.400956  0.101824
# C_where_prev                                         1.158037  0.282020
# C(block_type, Sum):C_where_prev                      1.324536  0.249935
# R_prev                                               7.848114  0.005143
# C(block_type, Sum):R_prev                            0.056075  0.812838
# R_prev:C_where_prev                                  0.383524  0.535803
# C(block_type, Sum):R_prev:C_where_prev               0.156593  0.692360
# R_prev:C_what_prev                                   1.024013  0.311708
# C(block_type, Sum):R_prev:C_what_prev                4.231755  0.039821
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   2.153582  0.001460
# C_what_curr:C_where_curr:C_what_prev                 2.036698  0.153720
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...   0.346696  0.556065
# R_prev:C_what_curr:C_where_curr                      0.006794  0.934318
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr   3.613020  0.057492
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.483057  0.069076
# R_prev:C_what_curr:C_where_curr:C_what_prev          1.461908  0.226789
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...   2.746765  0.097629
# Residual                                                  NaN       NaN
#                                                           sum_sq      df  \
# Intercept                                           4.371587e-04     1.0
# C(block_type, Sum)                                  4.469048e-05     1.0
# C(block_type, Sum):C(block_id, Sum)                 9.487700e-04    22.0
# C_what_curr:C_where_curr                            2.824818e-05     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         3.620800e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  1.529245e-03    22.0
# C_what_curr                                         4.060104e-06     1.0
# C(block_type, Sum):C_what_curr                      2.230490e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     6.019343e-04    22.0
# C_where_curr                                        1.281726e-06     1.0
# C(block_type, Sum):C_where_curr                     3.790840e-05     1.0
# R_curr                                              2.814007e-05     1.0
# C(block_type, Sum):R_curr                           3.012070e-05     1.0
# C_what_prev                                         2.358883e-06     1.0
# C(block_type, Sum):C_what_prev                      3.484225e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     1.104512e-03    22.0
# C_where_prev                                        1.768861e-05     1.0
# C(block_type, Sum):C_where_prev                     5.487681e-05     1.0
# R_prev                                              2.593287e-04     1.0
# C(block_type, Sum):R_prev                           6.730615e-09     1.0
# R_prev:C_where_prev                                 1.992932e-05     1.0
# C(block_type, Sum):R_prev:C_where_prev              6.465436e-06     1.0
# R_prev:C_what_prev                                  7.519901e-05     1.0
# C(block_type, Sum):R_prev:C_what_prev               8.381034e-05     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  1.830567e-03    22.0
# C_what_curr:C_where_curr:C_what_prev                1.002770e-04     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  2.910451e-07     1.0
# R_prev:C_what_curr:C_where_curr                     1.247933e-04     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  1.609221e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  1.078279e-03    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         3.159393e-05     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  9.829751e-05     1.0
# Residual                                            7.267485e-02  1765.0
#
#                                                             F    PR(>F)
# Intercept                                           10.616947  0.001142
# C(block_type, Sum)                                   1.085364  0.297643
# C(block_type, Sum):C(block_id, Sum)                  1.047367  0.400467
# C_what_curr:C_where_curr                             0.686043  0.407626
# C(block_type, Sum):C_what_curr:C_where_curr          0.879357  0.348506
# C(block_type, Sum):C(block_id, Sum):C_what_curr...   1.688165  0.023884
# C_what_curr                                          0.098605  0.753548
# C(block_type, Sum):C_what_curr                       0.541703  0.461826
# C(block_type, Sum):C(block_id, Sum):C_what_curr      0.664488  0.877184
# C_where_curr                                         0.031128  0.859975
# C(block_type, Sum):C_where_curr                      0.920653  0.337435
# R_curr                                               0.683417  0.408524
# C(block_type, Sum):R_curr                            0.731519  0.392507
# C_what_prev                                          0.057288  0.810862
# C(block_type, Sum):C_what_prev                       0.846188  0.357759
# C(block_type, Sum):C(block_id, Sum):C_what_prev      1.219294  0.219970
# C_where_prev                                         0.429590  0.512276
# C(block_type, Sum):C_where_prev                      1.332752  0.248472
# R_prev                                               6.298124  0.012175
# C(block_type, Sum):R_prev                            0.000163  0.989801
# R_prev:C_where_prev                                  0.484009  0.486704
# C(block_type, Sum):R_prev:C_where_prev               0.157021  0.691962
# R_prev:C_what_prev                                   1.826302  0.176738
# C(block_type, Sum):R_prev:C_what_prev                2.035439  0.153847
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   2.020801  0.003392
# C_what_curr:C_where_curr:C_what_prev                 2.435353  0.118806
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...   0.007068  0.933007
# R_prev:C_what_curr:C_where_curr                      3.030763  0.081874
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr   3.908195  0.048207
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...   1.190334  0.245639
# R_prev:C_what_curr:C_where_curr:C_what_prev          0.767298  0.381173
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...   2.387278  0.122506
# Residual                                                  NaN       NaN
#                                                           sum_sq      df  \
# Intercept                                           6.236012e-04     1.0
# C(block_type, Sum)                                  8.644291e-05     1.0
# C(block_type, Sum):C(block_id, Sum)                 1.727402e-03    22.0
# C_what_curr:C_where_curr                            7.691109e-05     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         4.323917e-06     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  2.141644e-03    22.0
# C_what_curr                                         1.943702e-05     1.0
# C(block_type, Sum):C_what_curr                      6.809065e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     8.243980e-04    22.0
# C_where_curr                                        1.360745e-06     1.0
# C(block_type, Sum):C_where_curr                     1.158229e-04     1.0
# R_curr                                              6.341268e-06     1.0
# C(block_type, Sum):R_curr                           1.786904e-06     1.0
# C_what_prev                                         1.523884e-06     1.0
# C(block_type, Sum):C_what_prev                      7.712048e-07     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     1.552074e-03    22.0
# C_where_prev                                        2.148104e-06     1.0
# C(block_type, Sum):C_where_prev                     4.196585e-05     1.0
# R_prev                                              3.392771e-04     1.0
# C(block_type, Sum):R_prev                           3.060784e-07     1.0
# R_prev:C_where_prev                                 2.843912e-04     1.0
# C(block_type, Sum):R_prev:C_where_prev              9.466938e-05     1.0
# R_prev:C_what_prev                                  1.175783e-04     1.0
# C(block_type, Sum):R_prev:C_what_prev               2.823233e-05     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  2.523545e-03    22.0
# C_what_curr:C_where_curr:C_what_prev                1.463373e-04     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  1.191393e-05     1.0
# R_prev:C_what_curr:C_where_curr                     3.821886e-04     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  1.535524e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  1.692960e-03    22.0
# ...
# R_prev:C_what_prev                                  0.196777  0.657390
# C(block_type, Sum):R_prev:C_what_prev               0.024394  0.875906
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  1.188346  0.247474
# C_what_curr:C_where_curr:C_what_prev                0.000990  0.974905
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  0.008930  0.924722
# R_prev:C_what_curr:C_where_curr                     0.043910  0.834046
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  3.799859  0.051415
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.951623  0.525056
# R_prev:C_what_curr:C_where_curr:C_what_prev         0.255660  0.613181
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  2.692314  0.101011
# Residual                                                 NaN       NaN
#                                                           sum_sq      df  \
# Intercept                                           2.597099e-04     1.0
# C(block_type, Sum)                                  1.584855e-05     1.0
# C(block_type, Sum):C(block_id, Sum)                 9.152182e-04    22.0
# C_what_curr:C_where_curr                            2.106089e-05     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         1.494832e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  1.723911e-03    22.0
# C_what_curr                                         7.092652e-05     1.0
# C(block_type, Sum):C_what_curr                      1.086240e-04     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     8.963957e-04    22.0
# C_where_curr                                        1.698698e-05     1.0
# C(block_type, Sum):C_where_curr                     5.329731e-07     1.0
# R_curr                                              4.416212e-06     1.0
# C(block_type, Sum):R_curr                           7.259933e-05     1.0
# C_what_prev                                         1.626279e-04     1.0
# C(block_type, Sum):C_what_prev                      3.549995e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     8.458689e-04    22.0
# C_where_prev                                        2.230162e-05     1.0
# C(block_type, Sum):C_where_prev                     3.469373e-08     1.0
# R_prev                                              2.290012e-06     1.0
# C(block_type, Sum):R_prev                           6.194281e-06     1.0
# R_prev:C_where_prev                                 1.231948e-04     1.0
# C(block_type, Sum):R_prev:C_where_prev              8.666615e-05     1.0
# R_prev:C_what_prev                                  1.861235e-06     1.0
# C(block_type, Sum):R_prev:C_what_prev               2.225561e-06     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  6.338391e-04    22.0
# C_what_curr:C_where_curr:C_what_prev                2.018118e-06     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  5.374031e-06     1.0
# R_prev:C_what_curr:C_where_curr                     9.962459e-06     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  1.142799e-04     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  6.522953e-04    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         2.771501e-06     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  6.318232e-05     1.0
# Residual                                            8.014026e-02  1765.0
#
#                                                            F    PR(>F)
# Intercept                                           5.719821  0.016879
# C(block_type, Sum)                                  0.349047  0.554729
# C(block_type, Sum):C(block_id, Sum)                 0.916212  0.573298
# C_what_curr:C_where_curr                            0.463843  0.495923
# C(block_type, Sum):C_what_curr:C_where_curr         0.329220  0.566192
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  1.725782  0.019406
# C_what_curr                                         1.562078  0.211527
# C(block_type, Sum):C_what_curr                      2.392324  0.122112
# C(block_type, Sum):C(block_id, Sum):C_what_curr     0.897369  0.599079
# C_where_curr                                        0.374119  0.540846
# C(block_type, Sum):C_where_curr                     0.011738  0.913736
# R_curr                                              0.097262  0.755177
# C(block_type, Sum):R_curr                           1.598919  0.206223
# C_what_prev                                         3.581698  0.058583
# C(block_type, Sum):C_what_prev                      0.781847  0.376697
# C(block_type, Sum):C(block_id, Sum):C_what_prev     0.846787  0.667656
# C_where_prev                                        0.491168  0.483499
# C(block_type, Sum):C_where_prev                     0.000764  0.977951
# R_prev                                              0.050435  0.822334
# C(block_type, Sum):R_prev                           0.136422  0.711908
# R_prev:C_where_prev                                 2.713229  0.099697
# C(block_type, Sum):R_prev:C_where_prev              1.908725  0.167280
# R_prev:C_what_prev                                  0.040992  0.839577
# C(block_type, Sum):R_prev:C_what_prev               0.049015  0.824811
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.634527  0.902070
# C_what_curr:C_where_curr:C_what_prev                0.044447  0.833049
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  0.118357  0.730864
# R_prev:C_what_curr:C_where_curr                     0.219412  0.639546
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  2.516887  0.112812
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.653003  0.887106
# R_prev:C_what_curr:C_where_curr:C_what_prev         0.061039  0.804890
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  1.391520  0.238308
# Residual                                                 NaN       NaN
#   0%|          | 0/564 [00:06<?, ?it/s]
#                                                           sum_sq      df  \
# Intercept                                           2.156360e-04     1.0
# C(block_type, Sum)                                  8.182009e-05     1.0
# C(block_type, Sum):C(block_id, Sum)                 1.035022e-03    22.0
# C_what_curr:C_where_curr                            2.458449e-05     1.0
# C(block_type, Sum):C_what_curr:C_where_curr         2.962152e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  2.224190e-03    22.0
# C_what_curr                                         7.525029e-05     1.0
# C(block_type, Sum):C_what_curr                      9.760548e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_curr     9.373469e-04    22.0
# C_where_curr                                        2.230759e-05     1.0
# C(block_type, Sum):C_where_curr                     6.189463e-06     1.0
# R_curr                                              1.322264e-05     1.0
# C(block_type, Sum):R_curr                           4.655886e-05     1.0
# C_what_prev                                         1.451625e-04     1.0
# C(block_type, Sum):C_what_prev                      8.253213e-05     1.0
# C(block_type, Sum):C(block_id, Sum):C_what_prev     1.170235e-03    22.0
# C_where_prev                                        9.214615e-06     1.0
# C(block_type, Sum):C_where_prev                     6.543499e-07     1.0
# R_prev                                              9.396153e-09     1.0
# C(block_type, Sum):R_prev                           6.333606e-06     1.0
# R_prev:C_where_prev                                 1.701484e-04     1.0
# C(block_type, Sum):R_prev:C_where_prev              1.270466e-04     1.0
# R_prev:C_what_prev                                  2.434157e-06     1.0
# C(block_type, Sum):R_prev:C_what_prev               4.628394e-06     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  4.131518e-04    22.0
# C_what_curr:C_where_curr:C_what_prev                9.191352e-06     1.0
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  1.611624e-05     1.0
# R_prev:C_what_curr:C_where_curr                     1.606423e-05     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  6.030182e-05     1.0
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  4.554759e-04    22.0
# R_prev:C_what_curr:C_where_curr:C_what_prev         3.095620e-07     1.0
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  1.928407e-05     1.0
# Residual                                            9.225176e-02  1765.0
#
#                                                            F    PR(>F)
# Intercept                                           4.125640  0.042388
# C(block_type, Sum)                                  1.565417  0.211040
# C(block_type, Sum):C(block_id, Sum)                 0.900113  0.595326
# C_what_curr:C_where_curr                            0.470361  0.492911
# C(block_type, Sum):C_what_curr:C_where_curr         0.566732  0.451661
# C(block_type, Sum):C(block_id, Sum):C_what_curr...  1.934279  0.005770
# C_what_curr                                         1.439721  0.230346
# C(block_type, Sum):C_what_curr                      1.867430  0.171944
# C(block_type, Sum):C(block_id, Sum):C_what_curr     0.815169  0.709296
# C_where_curr                                        0.426798  0.513649
# C(block_type, Sum):C_where_curr                     0.118419  0.730796
# R_curr                                              0.252981  0.615047
# C(block_type, Sum):R_curr                           0.890784  0.345394
# C_what_prev                                         2.777310  0.095786
# C(block_type, Sum):C_what_prev                      1.579040  0.209065
# C(block_type, Sum):C(block_id, Sum):C_what_prev     1.017702  0.437741
# C_where_prev                                        0.176298  0.674625
# C(block_type, Sum):C_where_prev                     0.012519  0.910924
# R_prev                                              0.000180  0.989304
# C(block_type, Sum):R_prev                           0.121177  0.727803
# R_prev:C_where_prev                                 3.255352  0.071361
# C(block_type, Sum):R_prev:C_where_prev              2.430710  0.119158
# R_prev:C_what_prev                                  0.046571  0.829166
# C(block_type, Sum):R_prev:C_what_prev               0.088552  0.766061
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.359300  0.997337
# C_what_curr:C_where_curr:C_what_prev                0.175853  0.675013
# C(block_type, Sum):C_what_curr:C_where_curr:C_w...  0.308343  0.578769
# R_prev:C_what_curr:C_where_curr                     0.307348  0.579383
# C(block_type, Sum):R_prev:C_what_curr:C_where_curr  1.153720  0.282919
# C(block_type, Sum):C(block_id, Sum):R_prev:C_wh...  0.396107  0.994573
# R_prev:C_what_curr:C_where_curr:C_what_prev         0.005923  0.938665
# C(block_type, Sum):R_prev:C_what_curr:C_where_c...  0.368951  0.543655
# Residual                                                 NaN       NaN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 80
#      76     print(anova_mdl)
#      78     return [mdl.params, omega_sq, pvals]
# ---> 80 linreg_anova_results = Parallel(n_jobs=1)(
#      81     delayed(run_linreg_anova)(time_idx) for time_idx in range(num_timesteps))
#      83 all_units_beta[:, unit_idx, :] = np.stack([curr_time_results[0] for curr_time_results in linreg_anova_results])
#      84 all_units_exp_var[:, unit_idx, :] = np.stack([curr_time_results[1] for curr_time_results in linreg_anova_results])
#
# File ~/opt/miniconda3/envs/layla/lib/python3.10/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/opt/miniconda3/envs/layla/lib/python3.10/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# Cell In[2], line 68, in run_linreg_anova(time_idx)
#      65 mdl = smf.ols(formula, tbl).fit()
#      67 # calculate anova
# ---> 68 anova_mdl = sm.stats.anova_lm(mdl, typ=3)
#      70 # calculate effect size for anova
#      71 ms_error = anova_mdl.loc[:,'sum_sq'].iloc[-1]/anova_mdl.loc[:,'sum_sq'].iloc[-1]
#
# File ~/opt/miniconda3/envs/layla/lib/python3.10/site-packages/statsmodels/stats/anova.py:353, in anova_lm(*args, **kwargs)
#     351 if len(args) == 1:
#     352     model = args[0]
# --> 353     return anova_single(model, **kwargs)
#     355 if typ not in [1, "I"]:
#     356     raise ValueError("Multiple models only supported for type I. "
#     357                      "Got type %s" % str(typ))
#
# File ~/opt/miniconda3/envs/layla/lib/python3.10/site-packages/statsmodels/stats/anova.py:87, in anova_single(model, **kwargs)
#      84     return anova2_lm_single(model, design_info, n_rows, test, pr_test,
#      85                             robust)
#      86 elif typ in [3, "III"]:
# ---> 87     return anova3_lm_single(model, design_info, n_rows, test, pr_test,
#      88                             robust)
#      89 elif typ in [4, "IV"]:
#      90     raise NotImplementedError("Type IV not yet implemented")
#
# File ~/opt/miniconda3/envs/layla/lib/python3.10/site-packages/statsmodels/stats/anova.py:256, in anova3_lm_single(model, design_info, n_rows, test, pr_test, robust)
#     253 r = L1.shape[0]
#     255 if test == 'F':
# --> 256     f = model.f_test(L12, cov_p=cov)
#     257     table.loc[table.index[i], test] = test_value = f.fvalue
#     258     table.loc[table.index[i], pr_test] = f.pvalue
#
# File ~/opt/miniconda3/envs/layla/lib/python3.10/site-packages/statsmodels/base/model.py:1786, in LikelihoodModelResults.f_test(self, r_matrix, cov_p, invcov)
#    1693 def f_test(self, r_matrix, cov_p=None, invcov=None):
#    1694     """
#    1695     Compute the F-test for a joint linear hypothesis.
#    1696
#    (...)
#    1784     <F test: F=array([[ 144.17976065]]), p=6.322026217355609e-08, df_denom=9, df_num=3>
#    1785     """
# -> 1786     res = self.wald_test(r_matrix, cov_p=cov_p, invcov=invcov, use_f=True, scalar=True)
#    1787     return res
#
# File ~/opt/miniconda3/envs/layla/lib/python3.10/site-packages/statsmodels/base/model.py:1893, in LikelihoodModelResults.wald_test(self, r_matrix, cov_p, invcov, use_f, df_constraints, scalar)
#    1889 if np.isnan(cov_p).max():
#    1890     raise ValueError("r_matrix performs f_test for using "
#    1891                      "dimensions that are asymptotically "
#    1892                      "non-normal")
# -> 1893 invcov = np.linalg.pinv(cov_p)
#    1894 J_ = np.linalg.matrix_rank(cov_p)
#    1895 if J_ < J:
#
# File ~/opt/miniconda3/envs/layla/lib/python3.10/site-packages/numpy/linalg/linalg.py:2022, in pinv(a, rcond, hermitian)
#    2020     return wrap(res)
#    2021 a = a.conjugate()
# -> 2022 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2024 # discard small singular values
#    2025 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File ~/opt/miniconda3/envs/layla/lib/python3.10/site-packages/numpy/linalg/linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#    1678         gufunc = _umath_linalg.svd_n_s
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1682 u = u.astype(result_t, copy=False)
#    1683 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
import patsy

# %%
curr_unit_time_fr = neural_data[:, 0, 0]
tbl = pd.DataFrame(np.concatenate([curr_unit_time_fr[:, None], X], axis=1),
                                        columns=['fr']+var_names_in_table)

# %%
yyy, XXX = patsy.dmatrices(formula, data=tbl, return_type='dataframe')

# %%
fig, axes = plt.subplots(figsize=(20,20))
im = axes.imshow(XXX.iloc[:,:], aspect='auto', interpolation='nearest')
fig.colorbar(im)

# %%
plt.imshow(X[:250], aspect='auto')

# %%
fig, axes = plt.subplots(figsize=(10,10))
im = axes.imshow(np.corrcoef(XXX.T)-np.eye(158))
plt.colorbar(im)
# Out:
# /Users/f005d7d/opt/miniconda3/envs/layla/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/f005d7d/opt/miniconda3/envs/layla/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
XXX.columns[:24]
# Out:
# Index(['Intercept', 'C(block_type, Sum)[S.-1.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.0.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.0.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.1.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.1.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.2.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.2.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.3.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.3.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.4.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.4.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.5.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.5.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.6.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.6.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.7.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.7.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.8.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.8.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.9.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.9.0]',
#        'C(block_type, Sum)[mean]:C(block_id, Sum)[S.10.0]',
#        'C(block_type, Sum)[S.-1.0]:C(block_id, Sum)[S.10.0]'],
#       dtype='object')
